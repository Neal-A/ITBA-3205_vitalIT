# %%
# Jovian Commit Essentials
# Please retain and execute this cell without modifying the contents for `jovian.commit` to work
# !pip install jovian --upgrade -q
import jovian
jovian.set_project('implementation-of-sex-education')
jovian.set_colab_id('1m2qQTY29tJ3ZqLKp_j-LsHJnGBRHJsCd')

# %% [markdown]
# # implementation-of-sex-education
#
# Use the "Run" button to execute the code.

# %% [markdown]
# ## Implementation of Sex Education Exploratory Data Analysis
# Todo - talk about EDA
# Todo - talk about the dataset (source, what it contains, how is it useful)
# - Philippine Statistics Authority
# - Data about Teenage Pregnancy
# - Can be used to highlight the importance of Sex Education

# %% [markdown]
# ## Download the Data

# %%
data_set1 = './data-sets/Summary of Birth Statistics in the Philippines (1903-2018).csv'

# %%
data_set2 = './data-sets/Number of Live Births M&F 2015.csv'

# %%
data_set3 = './data-sets/Number of Live Births M&F 2016.csv'

# %%
data_set4 = './data-sets/Number of Live Births M&F 2017.csv'

# %%
data_set5 = './data-sets/Number of Live Births M&F 2018.csv'

# %%
data_set6 = './data-sets/Number of Live Births M&F 2019.csv'

# %%
data_set7 = './data-sets/2020 APIS Household Head Age Group.csv'

# %%
data_set8 = './data-sets/2020 APIS Highest Grade Completed.csv'

# %%
data_set9 = './data-sets/APIS Reasons for not Attending.csv'

# %%
data_set10 = './data-sets/APIS Schooling status.csv'

# %% [markdown]
# ## Data Preparation and Cleaning

# %%
#import pandas package
import pandas as pd

# %%
#making df from csv files
df1 = pd.read_csv(data_set1)
df2 = pd.read_csv(data_set2)
df3 = pd.read_csv(data_set3)
df4 = pd.read_csv(data_set4)
df5 = pd.read_csv(data_set5)
df6 = pd.read_csv(data_set6)
df7 = pd.read_csv(data_set7)
df8 = pd.read_csv(data_set8)
df9 = pd.read_csv(data_set9)
df10 = pd.read_csv(data_set10)

# %%
#show entire df1 (change variable to check other df)
print(df10.to_string())

# %%
#check for datatype of each column (change variable to check other df)
print(df9.info())

# %% [markdown]
# ##DF1 cleaning

# %%
#check for null values in df1
bool_series=pd.isnull(df1["# of L.Births"] + df1["Population (1000)"] + df1["Birth Increase/Decrease"])
bool_series=pd.isnull(df1["Yr"])
bool_series=pd.isnull(df1["Crude B.R."] + df1["Percentage Change"])

# %%
#display data w/ null values from df1
df1[bool_series]

# %%
#drop all rows with null values in original df1
df1.dropna(inplace = True)

# %%
#display cleaned df1
print(df1.to_string())

# %% [markdown]
# ##DF8 cleaning

# %%
#check for null values in df8
bool_series=pd.isnull(df8["Grade"])
bool_series=pd.isnull(df8["M&F"] + df8["Male"] + df8["Female"])

# %%
#display data w/ null values from df8
df8[bool_series]

# %%
#drop rows with null values(2,15)
df8.drop(index = [2,15], inplace = True)

# %%
#replace missing values
df8.loc[[7,8],'Female'] = 0.1
df8.loc[7, 'Male'] = 0.1

# %%
#display cleaned df8
print(df8.to_string())

# %% [markdown]
# ##DF9 cleaning

# %%
#check for null values in df9
bool_series=pd.isnull(df9["M&F"] + df9["Male"] + df9["Female"])

# %%
#display data w/ null values from d9
df9[bool_series]

# %%
#replace missing values
#to complete the 100% total, the 0.1% was put on "Too young to go to school" since it was more appropriate to add there
df9.loc[[13,14],'Female'] = 0
df9.loc[13, 'M&F'] = 0
df9.loc[5,'Male'] = 0
df9.loc[13, 'Male'] = 0.1

# %%
#display cleaned df9
print(df9.to_string())

# %% [markdown]
# ##DF10 cleaning

# %%
#remove irrelevant row with null value
df10.dropna(inplace = True)

# %%
#display cleaned df10
print(df10.to_string())

# %% [markdown]
# ## Exploratory Analysis and Visualization

# %% [markdown]
# ## Ask & Answer Questions

# %% [markdown]
# ## Summary & Conclusion

# %% [markdown]
# ## SAVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="implementation-of-sex-education")
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Uploading colab notebook to Jovian...
# Committed successfully! https://jovian.ai/neal-a/implementation-of-sex-education
# 'https://jovian.ai/neal-a/implementation-of-sex-education'
